# %% [markdown]
# # Introduction
#
# Lino Galiana
# 2026-09-06
#
#
# <div class="callout callout-style-default callout-tip callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Skills you will acquire in this chapter
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# -   Understand why Python has become essential in the fields of *data science* and *data engineering*, thanks to its simplicity, readability, and strong community ecosystem
# -   Recognize how Python can support you through every stage of a data-driven project—from structuring and exploring data to modeling and communicating results
# -   Appreciate the value of a reproducible, rigorous, and scientific approach to *data science* and *data engineering*, and learn how to support this using tools like Jupyter notebooks, open data, and standardized environments
# -   Grasp the purpose and teaching goals of the course, as well as its main themes
#
# </div>
# </div>
#
# # 1. Introduction
#
# This course brings together all the material from the
# ***Python for Data Science*** class I’ve been teaching at [ENSAE](https://www.ensae.fr/courses/1425-python-pour-le-data-scientist) since 2020, and at [ENSAI](https://ensai.fr/) since 2026. More than 300 students now take this course each year.
#
#
# <div class="callout callout-style-default callout-note callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# International version
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# In 2024, an English version—equivalent to the French original—was gradually introduced. It is designed as an introductory *data science* course for European statistical institutes, following a [European call for projects](https://cros.ec.europa.eu/dashboard/aiml4os).
#
# </div>
# </div>
#
# The site ([pythonds.linogaliana.fr](https://pythonds.linogaliana.fr)) serves as the main hub for the course. It gathers all course content, including practical assignments and additional materials aimed at continuing education. The course is *open source*, and I welcome suggestions for improvement either on [`GitHub` ](https://github.com/linogaliana/python-datascientist) or in the comments section at the bottom of each page.
#
# Starting with the 2026 academic year, this course undergoes a major change: it is now split into two parts, taught across two semesters, allowing each to be covered in greater depth:
#
# -   Python for *data* in the first semester, corresponding to the first part of the course focused on data exploration;
# -   Python for *ML* in the second semester, corresponding to the second part of the course focused on modeling.
#
# Because `Python` is a living, fast-evolving language, the course is continuously updated to reflect the changing *data science* ecosystem. At the same time, it strives to differentiate lasting trends from short-lived fads.
#
# While this course is primarily aimed at *data science* students, it is general enough to be of interest to a wide range of profiles—students and professionals alike—coming from diverse academic backgrounds. It is designed as an introduction to *data science* through Python.
#
#
# <div class="callout callout-style-default callout-tip callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Going further
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# You can find more information in the [introductory slides](https://slidespython.linogaliana.fr/). More advanced topics are covered in another course focused on deploying *data science* projects to production, which I co-teach with Romain Avouac in the final year at ENSAE ([ensae-reproductibilite.github.io/website](https://ensae-reproductibilite.github.io/website)), with a variant of it soon to be taught at ENSAI as well.
#
# </div>
# </div>
#
#
# <div class="callout callout-style-default callout-note callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Website Architecture
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# This course offers comprehensive tutorials and exercises that can be read directly on the site or edited and run in an interactive `Jupyter Notebook` environment (see the [next chapter](../../content/getting-started/01_environment.qmd) for details).
#
# Each page is built around a concrete problem and introduces a general approach to solving it. All examples are based on *open data* and are fully reproducible.
#
# You can navigate the site using the table of contents or the previous/next links at the bottom of each page. Some sections - such as the one on modeling - include highlighted examples that illustrate the methodology and present different possible approaches to solving the same problem.
#
# </div>
# </div>
#
# # 2. Why `Python` ?
#
# `Python` whose recognizable logo appears as , is a language that’s been around for over thirty years. But it was in the 2010s that it experienced a major resurgence, driven by the growing popularity of *data science*.
#
# More than any other language, `Python` brings together a wide range of communities: statisticians, application developers, IT infrastructure managers, high school students (it has been part of the French baccalaureate curriculum for several years), and researchers in both theoretical and applied fields.
#
# Unlike many programming languages that cater to relatively homogeneous communities, `Python` has succeeded in uniting diverse users thanks to a few key principles: its readable syntax, the simplicity of using modules, the ease of integration with more powerful languages for specific tasks, and the vast amount of online documentation. Sometimes, being the second-best tool for a task—while offering a broader set of advantages—can be the key to success.
#
# `Python` success story is closely tied to the rise of the *data scientist* role, a profile capable of working across the entire data processing pipeline. In the *Harvard Business Review*, Davenport and Patil (2012) famously called it “the sexiest job of the 21st century.” A decade later, he and his co-authors provided a full update on the evolving expectations for *data scientists* (Davenport and Patil 2022).
#
# But it’s not only *data scientists* who need to use `Python`. In the broader ecosystem of data-related professions—*data scientists*, *data engineers*, *ML engineers*, and more—`Python` serves as a kind of Tower of Babel, enabling collaboration among interdependent roles[1].
#
# This course introduces various tools that use `Python` to connect data with theoretical concepts from statistics and the economic and social sciences. However, it goes beyond a simple introduction to the language: it regularly reflects on both the strengths and the limitations of `Python` in meeting operational and scientific needs.
#
# # 3. Why use `Python`  for data analysis?
#
# This question is slightly different: if `Python` is already a popular language for learning programming due to its ease of use, how did it also become the dominant language in the *data* and AI ecosystem?
#
# Python first gained traction in the *data science* world for offering tools to train *machine learning* algorithms, even before such approaches became mainstream. Of course, the success of libraries like [`Scikit-Learn`](https://scikit-learn.org/stable/), [`TensorFlow`](https://www.tensorflow.org/), and more recently [`PyTorch`](https://pytorch.org/), played a major role in `Python`’s adoption by the *data science* community[2]. However, reducing `Python` to a handful of *machine learning* libraries would be overly simplistic. It is truly a Swiss Army knife for *data scientists*, social scientists, economists, and data practitioners of all kinds. Its success is not only due to offering the right tools at the right time, but also because the language itself offers real advantages for newcomers to data work.
#
# What makes `Python` appealing is its central role in a broader ecosystem of powerful, flexible, and open-source tools. Like , it belongs to a category of languages suitable for everyday use across a wide variety of tasks. In many of the fields covered in this course, `Python` has by far the richest and most accessible ecosystem. Unlike other popular languages such as `JavaScript` or `Rust`, it has a very gentle learning curve, allowing users to write high-quality code quickly - provided they learn the right habits, which this course (and the companion course on [production workflows](https://ensae-reproductibilite.github.io/)) aims to instill.
#
# Beyond AI projects\[^nte-ia-en\], `Python` is also indispensable for retrieving data via APIs or through *web scraping*[3], two techniques introduced early in the course. In areas like tabular data analysis[4], web publishing or data visualization, `Python` now offers an ecosystem comparable to , thanks in part to growing investment from [`Posit`](https://posit.co/), which has ported many of ’s most successful libraries—such as [ggplot](https://ggplot2.tidyverse.org/) to `Python`[5].
#
# **Tabular data** is structured data, organized — as the name suggests — in table form, mapping observations to variables. This structure contrasts with other, more complex data types: free text, images, audio, video…
#
# > **Note 3.1**
# >
# > <div class="callout callout-style-default callout-note callout-titled" id="nte-ia-en">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Why discuss AI so little in a Python    course?
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > While a significant portion of this course covers *machine learning* and related algorithms, I tend to resist the current trend - especially strong since the release of `ChatGPT` in late 2022 - of labeling everything as “AI”.
# >
# > First, because the term is vague, overused, and often exploited for marketing purposes, capitalizing on its symbolic power drawn from science fiction to sell miracle solutions or stoke fear.
# >
# > Second, because the term “AI” covers a vast range of possible methods, depending on how broadly we define it. The sections on modeling and NLP in this course, which are the closest to the AI field, focus on learning-based methods. But as definitions from Russell and Norvig (2020) or the [European AI Act](https://artificialintelligenceact.eu/fr/article/3/) show, artificial intelligence encompasses much more:
# >
# > > The study of \[intelligent\] agents that perceive their environment and act upon it. Each such agent is implemented by a function that maps perceptions to actions. We study different ways to define this function, such as production systems, reactive agents, logical planners, neural networks, and decision-theoretic systems.
# > >
# > > Russell and Norvig (2020)
# >
# > > “AI system” means a machine-based system designed to operate with varying levels of autonomy and capable of adapting after deployment. It infers, based on its inputs, how to generate outputs—such as predictions, content, recommendations, or decisions—that can influence physical or virtual environments.
# > >
# > > [European AI Act](https://artificialintelligenceact.eu/fr/article/3/)
# >
# > For more on this topic, see a presentation I gave in 2024 (in French):
# >
# > <details>
# > <summary><p>Scroll the <em>slides</em> or open in <a
# > href="https://linogaliana.github.io/20241015-prez-ia-masa/#/title-slide/">full
# > screen</a>.</p></summary>
# > <div class="sourceCode">
# > <iframe class="sourceCode" src="https://linogaliana.github.io/20241015-prez-ia-masa/#/title-slide/"></iframe>
# >
# > </div>
# > </details>
# >
# > Finally, there’s also a pedagogical reason. Since 2023, “AI” has largely become synonymous with generative AI. But to understand how this radically different paradigm works - and to implement meaningful, value-driven generative AI projects - one must first understand the foundations and limitations of the *machine learning* approach. Otherwise, there’s a risk of building overly complex solutions for simple problems or misjudging the value of generative models compared to more traditional methods. Since this is an introductory course, I’ve chosen to focus on *machine learning* and introductory NLP, deep enough to be meaningful, while leaving it to the curious to explore generative AI further on their own.
# >
# > </div>
# > </div>
#
# # 4. Why learn `Python` when code-generating AIs exist?
#
# Code assistants, especially `Claude` and `ChatGPT`, have changed the way we write code forever. The pace of change is quite staggering.
#
# These tools are now part of the everyday toolkit of *data scientists* and offer real convenience, since they can generate `Python` code from instructions that are more or less clearly specified. And because these AIs have been trained on virtually all the code available on the internet—and are sometimes specialized for development tasks—they help a great deal.
#
# The integration of *vibe coding* tools into IDEs (particularly `Claude Code`) has accelerated this process even further and poses a real challenge for education.
#
# So, if AIs can now generate code, why should we still learn how to code?
#
# ## 4.1 Because coding means solving an engineering problem
#
# Because coding is not just about writing lines of code. It’s about understanding a problem, crafting a step-by-step strategy to tackle it, considering multiple solutions and trade-offs (e.g., speed, simplicity), testing and debugging. Code is a means to an engineering end. While AIs are very good at generating code, relating problems to known patterns, and even translating solutions across languages into `Python`, that’s only part of the picture.
#
# But you still need to know how to formulate the problem, how to judge the quality of the LLM’s answer, and how to challenge the assistant’s suggestion in order to fix a mistake or get a more satisfying answer. LLMs are a highly (very highly) refined version of a *Google* search: if you don’t have the right keywords for a Google search, your search will be disappointing. The same goes for LLMs, even though the conversational, natural-language aspect lowers the barrier to entry.
#
# Code is not an end in itself, but a tool in service of structured reasoning aimed at solving a concrete problem.
#
# Working with a dataset, and searching for answers that aren’t obvious, raises a variable mix of scientific and engineering questions. Like an engineer designing a bridge, who works to meet the need to cross a gap using the scientific knowledge and materials available, the *data scientist* starts from an operational goal (building a recommendation algorithm, measuring the impact of a product launch, forecasting sales) and turns it into something workable. This means translating scientific or *business* concepts into analytical questions, then breaking the problem down into logical steps, each of which is translated into instructions the machine can execute.
#
# In this context, an LLM can act as an assistant, but only if the problem is well posed. If the steps are vague or poorly defined, the model’s answer will be approximate, or even useless. The frontier keeps being pushed back thanks to models’ growing reasoning capabilities, but these tools remain limited. On a standard task, the result may look correct, but on a more specific question, it will often be necessary to refine, rephrase, iterate… and sometimes never get a satisfactory answer. Not because the model is bad, but because upstream problem engineering makes all the difference[6].
#
# ## 4.2 Because coding means thinking
#
# What’s more, if we don’t take the time, during our studies, to grapple with these problems and to learn, when will we ever have the time to do so? Although we still have little hindsight on this topic, cognitive science research is starting to accumulate evidence of a negative effect of AI use on the brain (see the concept of “cognitive debt” in Kosmyna et al. (2025)).
#
# This isn’t about being nostalgic for the golden days when you could spend hours racking your brain over a coding problem that an AI can now solve in minutes, or even seconds. I myself use generative AI every day to help generate code or create content (for instance, for the automatic translation of this course into English). That said, it’s worth remembering that the goal is to enable more *deep work* (and to enjoy it!), not to end up as a mere alienated machine, condemned to clicking the *“Yes”* button as fast as possible whenever Claude asks for permission. This is a hard balance to strike, since the tools available today tend to make us dependent on them. The best way to avoid becoming captive to these tools remains acquiring—and continuing to build throughout one’s career—general skills: that is the ambition of this applied *data science* course.
#
# ## 4.3 Because coding means constantly updating your knowledge
#
# One last reason not to rely on a code-generating AI without critical distance is that these tools are inevitably behind current practice, since they were trained on past data. The `Python` ecosystem is highly dynamic, and even though the AIs from major providers are frequently retrained and can now access the internet to refresh their knowledge, certain libraries can quickly establish themselves in their field.
#
# For instance, last year [`uv`](https://docs.astral.sh/uv/) saw rapid adoption, as did [`ruff`](https://docs.astral.sh/ruff/) the year before. The existence of generative AIs does not, therefore, exempt us, as before, from keeping an active technical watch and being vigilant about changes in practices.
#
# # 5. Course Objectives
#
# ## 5.1 Introducing the data science approach
#
# This course is intended for practitioners of *data science*, understood here in the broadest sense as the **combination of techniques from mathematics, statistics, and computer science to extract useful knowledge from data**.
#
# Since *data science* is not only an academic discipline but also a practical field aimed at achieving operational goals, learning its main tool—namely, the `Python` programming language—goes hand in hand with adopting a rigorous, scientific approach to data.
#
# The objective of this course is to explore how to approach a dataset, identify and address common challenges, develop appropriate solutions, and reflect on their broader implications. It is therefore not merely a course about a technical tool, disconnected from scientific reasoning, but one rooted in understanding data through both technical and conceptual lenses.
#
#
# <div class="callout callout-style-default callout-tip callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Do I need a math background for this course?
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# This course assumes you are interested in using data-intensive `Python` within a rigorous statistical framework. It does not delve deeply into the statistical or algorithmic foundations of the techniques presented - many of which are covered in dedicated courses, particularly at ENSAE.
#
# That said, not being familiar with these concepts shoud not prevent from following this course. More advanced ideas are typically introduced separately, in dedicated callout boxes. Thanks to Python’s ease of use, you will not need to implement complex models from scratch - making it possible to apply techniques even if you are not an expert in the underlying theory. What *is* important, however, is having enough understanding to correctly interpret the results.
#
# Still, while `Python` makes it relatively easy to run sophisticated models, it is very helpful to have some perspective before diving into modeling. That explains why modeling appears later in the course: in addition to relying on advanced statistical concepts, effective modeling also requires a solid understanding of the data. You need to identify key patterns and assess whether your data fits the assumptions of the model. Without this foundation, it is difficult to build models that are truly meaningful or reliable.
#
# </div>
# </div>
#
# ## 5.2 Reproducibility
#
# This course places strong emphasis on reproducibility. This principle is reflected in several ways. First and foremost, by ensuring that all examples and exercises can be run and tested using `Jupyter` *notebooks*.
#
# A *notebook* is an interactive environment for writing and running code live. It combines, in a single document, text and code that can be executed, with outputs displayed right after computation. It’s extremely convenient for learning the `Python` language.
#
# For more details, see the [official Jupyter documentation](https://jupyter.org/documentation).
#
# All content on the website is designed to be reproducible across different computing environments. Of course, you’re free to copy and paste code snippets directly from the site using the button available at the top of each code block.
#
# [1] See Galiana and Lefebvre (2026) for more context on the evolving landscape of data-related jobs.
#
# [2] [`Scikit-Learn`](https://scikit-learn.org/stable/) is a library developed since 2007 by French public research labs at INRIA. Open source from the outset, it is now maintained by [`:probabl.`](https://probabl.ai/), a startup created to manage the `Scikit` ecosystem, bringing together some of the INRIA research teams behind the core of the modern *machine learning* stack.
#
# [`TensorFlow`](https://www.tensorflow.org/) was developed internally at Google and made public in 2015. Although now less widely used - partly due to the rise of `PyTorch` - it played a major role in popularizing neural networks in both research and production during the 2010s.
#
# [`PyTorch`](https://pytorch.org/) was developed by Meta starting 2018 and has been governed by the [*PyTorch Foundation*](https://pytorch.org/foundation) since 2022. It is now the most widely used framework to train neural networks.
#
# [3] In the domains of API access and *web scraping*, `JavaScript` is `Python`’s most serious competitor. However, its community is more focused on web development than on *data science*.
#
# [4] In the field of unstructured data, `Python` is the dominant analysis language. For tabular data, `Python`’s competitive edge is smaller, particularly compared to , but the two languages offer a fairly similar core set of features. We will regularly draw parallels between them in the chapters devoted to the `Pandas` library.
#
# That said, this course does not aim to stir up the sterile debate between and `Python`.
#
# The two languages share far more than they differ, and best practices are easily transferable from one to the other. This idea is explored in more depth in the more advanced course I co-teach with Romain Avouac in the final year at ENSAE: [ensae-reproductibilite.github.io/website](https://ensae-reproductibilite.github.io/website).
#
# [5] In practice, data scientists and researchers in the social sciences or economics increasingly use and `Python` almost interchangeably, switching between the two. This course will therefore regularly draw analogies with to help those discovering `Python`, but already familiar with , better understand certain points.
#
# [6] On this topic, see Thomas Wolf’s blog post [*The Einstein AI model*](https://thomwolf.io/blog/scientific-ai.html). Although the post focuses on disruptive innovation and pays less attention to incremental progress, it’s insightful in understanding that LLMs—despite bold predictions from tech influencers—are still just tools. They may excel at standardized tasks, but for now, they remain assistants.

# %%
x = "Try to copy-paste me"

# %% [markdown]
# However, since this site includes many examples, constantly switching between a `Python` environment and the website can become tedious. To make things easier, each chapter can be downloaded as a `Jupyter` *notebook* using the buttons provided at the top of each page.
#
# For example, here are the buttons for the first chapter on `Pandas`:
#
# <div class="badge-container"><a href="https://github.com/linogaliana/python-datascientist-notebooks/blob/main/notebooks/en/manipulation/02_pandas_intro.ipynb" class="badge" target="_blank" rel="noopener"><img src="https://img.shields.io/static/v1?logo=github&label=&message=View%20on%20GitHub&color=181717" alt="View on GitHub"></a>
# <a href="https://datalab.sspcloud.fr/launcher/ide/vscode-python?autoLaunch=true&name=«02_pandas_intro»&init.personalInit=«https%3A%2F%2Fraw.githubusercontent.com%2Flinogaliana%2Fpython-datascientist%2Fmain%2Fsspcloud%2Finit-vscode.sh»&init.personalInitArgs=«en/manipulation%2002_pandas_intro»" class="badge" target="_blank" rel="noopener"><img src="https://custom-icon-badges.demolab.com/badge/SSP%20Cloud-Lancer_avec_VSCode-blue?logo=vsc&logoColor=white" alt="Onyxia"></a>
# <a href="https://colab.research.google.com/github/linogaliana/python-datascientist-notebooks-colab//en/blob/main//notebooks/en/manipulation/02_pandas_intro.ipynb" class="badge" target="_blank" rel="noopener"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
# <a href="https://codespaces.new/linogaliana/python-datascientist-notebooks?quickstart=1&ref=main" class="badge" target="_blank" rel="noopener"><img src="https://github.com/codespaces/badge.svg" alt="Open in GitHub Codespaces"></a><br></div>
#
# Recommendations on the best environments for using these notebooks are provided in the next chapter.
#
# The focus on reproducibility is also reflected in the choice of examples used throughout the course. All content on this site is based on *open data*, sourced either from French platforms - primarily the centralized portal [`data.gouv`](https://www.data.gouv.fr), which aggregates public datasets from French institutions, or the official statistics agency [Insee](https://www.insee.fr), France’s national institute for statistics and economic studies - or from U.S. datasets. This ensures that results are reproducible for anyone working in an identical environment[1].
#
#
# <div class="callout callout-style-default callout-note callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Note
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# American researchers have described a reproducibility crisis in the field of *machine learning* (**Reproducibilitycrisis-en?**). The distortions of the scientific publishing ecosystem - combined with the economic incentives driving academic publications in *machine learning* - are often cited as major contributing factors.
#
# However, university education also bears a share of the responsibility. Students and researchers are rarely trained in the principles of reproducibility, and if these practices are not introduced early in their careers, they are unlikely to adopt them later. This is why, in addition to teaching `Python` and *data science*, this course includes a dedicated section on using version control with `Git` .
#
# All student projects are required to be *open source*—one of the most effective ways for instructors to encourage high-quality, transparent, and reproducible code.
#
# </div>
# </div>
#
# ## 5.3 Assessment
#
# Students at ENSAE and ENSAI complete the course by working on an in-depth project. Details on how the course is assessed, along with a list of past student projects, can be found in the [Evaluation](../../content/annexes/evaluation) section.
#
# # 6. Course Outline
#
# This course serves as an introduction to the core challenges of *data science* through learning the `Python` programming language. As the term *“data science”* implies, a significant portion of the course is dedicated to working directly with data: retrieving it, structuring it, exploring it, and combining it.
#
# These topics are covered in the first part of the course, [“Manipulating Data”](../../content/manipulation/index.qmd), which lays the foundation for everything that follows. Unfortunately, many training programs in *data science*, applied statistics, or the economic and social sciences tend to overlook this crucial aspect of a data scientist’s work—often referred to as [“data wrangling”](https://en.wikipedia.org/wiki/Data_wrangling) or [*“feature engineering”*](https://en.wikipedia.org/wiki/Feature_engineering). And yet, not only does it represent a large share of the day-to-day work in data science, it’s also essential for building relevant and accurate models.
#
# The goal of this first section is to highlight the challenges involved in accessing and leveraging different types of data sources using `Python`. The examples are diverse, reflecting the variety of data that can be analyzed with `Python`: municipal $CO_2$ emissions in France, real estate transaction records, housing energy performance diagnostics, bike-sharing data from the Velib system, and more.
#
# The second part of the course focuses on creating visualizations with `Python`. Once your data has been cleaned and processed, you’ll typically want to summarize it—through tables, graphs, or maps. This part, [“Communicating with Python”](../../content/visualization/index.qmd), offers a concise introduction to the topic. While somewhat introductory, it provides essential concepts that will be reinforced later in the course.
#
# The third part centers on modeling, using electoral science as the main example ([“Modeling with Python”](../../content/modelisation/index.qmd)). This section introduces the scientific reasoning behind *machine learning*, explores both methodological and technical choices, and sets the stage for deeper topics addressed later in the program.
#
# The fourth part takes a step back to focus on the specific challenges of working with text data. This is the [“Introduction to Natural Language Processing (NLP) with Python”](../../content/NLP/index.qmd) chapter. Given that NLP is a rapidly evolving field, this section serves only as an introduction. For more advanced coverage, see Russell and Norvig (2020), chapter 24.
#
# This chapter also includes a section on version control with `Git` ([Discover `Git`](../../content/git/index.qmd)). Why include this in a course about `Python` ? Because learning `Git` helps you write better code, collaborate effectively, and test or share your work in reproducible environments. This is especially valuable in a world where platforms like [`GitHub`](https://github.com/) act as professional showcases—and where companies and public institutions increasingly expect their *data scientists* to be proficient with `Git`.
#
# For more advanced applications, including deployment and reproducibility, refer to the companion course on [putting data science projects into production](https://ensae-reproductibilite.github.io/).
#
# In more detail, here is the course outline:
#
# ### Introduction
#
# [1] Opening the chapters as *notebooks* in standardized environments - something explained in the next chapter - ensures you are working in a controlled setup. Personal `Python` installations often involve tweaks and adjustments that can alter your environment and lead to unexpected, hard-to-diagnose errors. For this reason, such local setups are not recommended for this course. As you’ll see in the next chapter, *cloud-based* environments offer the advantage of consistent, preconfigured setups that greatly improve reliability and ease of use.

# %% [raw]
# <div id="yvdjgqnerp" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #yvdjgqnerp table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #yvdjgqnerp thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #yvdjgqnerp p { margin: 0; padding: 0; }
#  #yvdjgqnerp .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #yvdjgqnerp .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #yvdjgqnerp .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #yvdjgqnerp .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #yvdjgqnerp .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #yvdjgqnerp .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #yvdjgqnerp .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #yvdjgqnerp .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #yvdjgqnerp .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #yvdjgqnerp .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #yvdjgqnerp .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #yvdjgqnerp .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #yvdjgqnerp .gt_spanner_row { border-bottom-style: hidden; }
#  #yvdjgqnerp .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #yvdjgqnerp .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #yvdjgqnerp .gt_from_md> :first-child { margin-top: 0; }
#  #yvdjgqnerp .gt_from_md> :last-child { margin-bottom: 0; }
#  #yvdjgqnerp .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #yvdjgqnerp .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #yvdjgqnerp .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #yvdjgqnerp .gt_row_group_first td { border-top-width: 2px; }
#  #yvdjgqnerp .gt_row_group_first th { border-top-width: 2px; }
#  #yvdjgqnerp .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #yvdjgqnerp .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #yvdjgqnerp .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #yvdjgqnerp .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #yvdjgqnerp .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #yvdjgqnerp .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #yvdjgqnerp .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #yvdjgqnerp .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #yvdjgqnerp .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #yvdjgqnerp .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #yvdjgqnerp .gt_left { text-align: left; }
#  #yvdjgqnerp .gt_center { text-align: center; }
#  #yvdjgqnerp .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #yvdjgqnerp .gt_font_normal { font-weight: normal; }
#  #yvdjgqnerp .gt_font_bold { font-weight: bold; }
#  #yvdjgqnerp .gt_font_italic { font-style: italic; }
#  #yvdjgqnerp .gt_super { font-size: 65%; }
#  #yvdjgqnerp .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #yvdjgqnerp .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #yvdjgqnerp .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #yvdjgqnerp .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #yvdjgqnerp .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #yvdjgqnerp .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/getting-started/index.qmd">Introduction</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/getting-started/01_environment.qmd">A functional Python environment for data science</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/getting-started/02_data_analysis.qmd">How to deal with a data set</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/getting-started/03_revisions.qmd">A few refresher exercises to get back in the saddle</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Manipuler des données

# %% [raw]
# <div id="vwudooazcq" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #vwudooazcq table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #vwudooazcq thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #vwudooazcq p { margin: 0; padding: 0; }
#  #vwudooazcq .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #vwudooazcq .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #vwudooazcq .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #vwudooazcq .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #vwudooazcq .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #vwudooazcq .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #vwudooazcq .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #vwudooazcq .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #vwudooazcq .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #vwudooazcq .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #vwudooazcq .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #vwudooazcq .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #vwudooazcq .gt_spanner_row { border-bottom-style: hidden; }
#  #vwudooazcq .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #vwudooazcq .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #vwudooazcq .gt_from_md> :first-child { margin-top: 0; }
#  #vwudooazcq .gt_from_md> :last-child { margin-bottom: 0; }
#  #vwudooazcq .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #vwudooazcq .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #vwudooazcq .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #vwudooazcq .gt_row_group_first td { border-top-width: 2px; }
#  #vwudooazcq .gt_row_group_first th { border-top-width: 2px; }
#  #vwudooazcq .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #vwudooazcq .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #vwudooazcq .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #vwudooazcq .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #vwudooazcq .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #vwudooazcq .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #vwudooazcq .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #vwudooazcq .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #vwudooazcq .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #vwudooazcq .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #vwudooazcq .gt_left { text-align: left; }
#  #vwudooazcq .gt_center { text-align: center; }
#  #vwudooazcq .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #vwudooazcq .gt_font_normal { font-weight: normal; }
#  #vwudooazcq .gt_font_bold { font-weight: bold; }
#  #vwudooazcq .gt_font_italic { font-style: italic; }
#  #vwudooazcq .gt_super { font-size: 65%; }
#  #vwudooazcq .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #vwudooazcq .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #vwudooazcq .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #vwudooazcq .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #vwudooazcq .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #vwudooazcq .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/index.qmd">Introduction to part 1: data wrangling</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/01_numpy.qmd">Numpy, the foundation of data science</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/02_pandas_intro.qmd">Introduction to Pandas</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #2 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/02_pandas_joins.qmd">Associating data with Pandas: joins</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #2 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/02_pandas_stats.qmd">Data wrangling with Pandas: statistics and reshaping</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #2 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/02_pandas_beyond.qmd">Pandas: limitations and alternative ecosystems</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #2 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/03_geopandas_intro.qmd">Introduction to spatial data with Geopandas</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #4 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/04a_webscraping_TP.qmd">Web scraping with Python</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/04c_API_TP.qmd">Retrieve data with APIs from Python</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #4 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/04b_regex_TP.qmd">Mastering regular expressions</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/05_parquet_s3.qmd">New ways of accessing data: Parquet format and data in the cloud</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Communiquer

# %% [raw]
# <div id="ovzvgmxens" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #ovzvgmxens table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ovzvgmxens thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ovzvgmxens p { margin: 0; padding: 0; }
#  #ovzvgmxens .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #ovzvgmxens .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ovzvgmxens .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #ovzvgmxens .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #ovzvgmxens .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ovzvgmxens .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ovzvgmxens .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ovzvgmxens .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ovzvgmxens .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ovzvgmxens .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ovzvgmxens .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ovzvgmxens .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ovzvgmxens .gt_spanner_row { border-bottom-style: hidden; }
#  #ovzvgmxens .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ovzvgmxens .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #ovzvgmxens .gt_from_md> :first-child { margin-top: 0; }
#  #ovzvgmxens .gt_from_md> :last-child { margin-bottom: 0; }
#  #ovzvgmxens .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #ovzvgmxens .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #ovzvgmxens .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ovzvgmxens .gt_row_group_first td { border-top-width: 2px; }
#  #ovzvgmxens .gt_row_group_first th { border-top-width: 2px; }
#  #ovzvgmxens .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #ovzvgmxens .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #ovzvgmxens .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #ovzvgmxens .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #ovzvgmxens .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ovzvgmxens .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #ovzvgmxens .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #ovzvgmxens .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #ovzvgmxens .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ovzvgmxens .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ovzvgmxens .gt_left { text-align: left; }
#  #ovzvgmxens .gt_center { text-align: center; }
#  #ovzvgmxens .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ovzvgmxens .gt_font_normal { font-weight: normal; }
#  #ovzvgmxens .gt_font_bold { font-weight: bold; }
#  #ovzvgmxens .gt_font_italic { font-style: italic; }
#  #ovzvgmxens .gt_super { font-size: 65%; }
#  #ovzvgmxens .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ovzvgmxens .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #ovzvgmxens .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ovzvgmxens .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ovzvgmxens .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ovzvgmxens .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/visualisation/index.qmd">Introduction to part 2: communicating with data</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/visualisation/matplotlib.qmd">Building graphics with Python</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/visualisation/maps.qmd">Introduction to cartography with Python</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Modéliser

# %% [raw]
# <div id="imcnyakrab" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #imcnyakrab table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #imcnyakrab thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #imcnyakrab p { margin: 0; padding: 0; }
#  #imcnyakrab .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #imcnyakrab .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #imcnyakrab .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #imcnyakrab .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #imcnyakrab .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #imcnyakrab .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #imcnyakrab .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #imcnyakrab .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #imcnyakrab .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #imcnyakrab .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #imcnyakrab .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #imcnyakrab .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #imcnyakrab .gt_spanner_row { border-bottom-style: hidden; }
#  #imcnyakrab .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #imcnyakrab .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #imcnyakrab .gt_from_md> :first-child { margin-top: 0; }
#  #imcnyakrab .gt_from_md> :last-child { margin-bottom: 0; }
#  #imcnyakrab .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #imcnyakrab .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #imcnyakrab .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #imcnyakrab .gt_row_group_first td { border-top-width: 2px; }
#  #imcnyakrab .gt_row_group_first th { border-top-width: 2px; }
#  #imcnyakrab .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #imcnyakrab .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #imcnyakrab .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #imcnyakrab .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #imcnyakrab .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #imcnyakrab .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #imcnyakrab .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #imcnyakrab .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #imcnyakrab .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #imcnyakrab .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #imcnyakrab .gt_left { text-align: left; }
#  #imcnyakrab .gt_center { text-align: center; }
#  #imcnyakrab .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #imcnyakrab .gt_font_normal { font-weight: normal; }
#  #imcnyakrab .gt_font_bold { font-weight: bold; }
#  #imcnyakrab .gt_font_italic { font-style: italic; }
#  #imcnyakrab .gt_super { font-size: 65%; }
#  #imcnyakrab .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #imcnyakrab .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #imcnyakrab .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #imcnyakrab .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #imcnyakrab .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #imcnyakrab .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/index.qmd">Introduction to part 3: modelisation</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #5 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/0_preprocessing.qmd">Preprocessing before building machine learning models</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #5 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/1_modelevaluation.qmd">Evaluating model quality</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #5 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/2_classification.qmd">Discovering classification with decision trees</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #5 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/3_regression.qmd">An introduction to regression</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #6 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/4_featureselection.qmd">Variable selection: an introduction</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #6 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/5_clustering.qmd">Clustering</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #6 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/6_pipeline.qmd">Premier pas vers l'industrialisation avec les pipelines scikit</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/7_mlapi.qmd">Mettre à disposition un modèle par le biais d'une API</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Natural Language Processing (NLP)

# %% [raw]
# <div id="vkokdcwdzm" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #vkokdcwdzm table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #vkokdcwdzm thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #vkokdcwdzm p { margin: 0; padding: 0; }
#  #vkokdcwdzm .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #vkokdcwdzm .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #vkokdcwdzm .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #vkokdcwdzm .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #vkokdcwdzm .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #vkokdcwdzm .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #vkokdcwdzm .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #vkokdcwdzm .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #vkokdcwdzm .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #vkokdcwdzm .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #vkokdcwdzm .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #vkokdcwdzm .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #vkokdcwdzm .gt_spanner_row { border-bottom-style: hidden; }
#  #vkokdcwdzm .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #vkokdcwdzm .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #vkokdcwdzm .gt_from_md> :first-child { margin-top: 0; }
#  #vkokdcwdzm .gt_from_md> :last-child { margin-bottom: 0; }
#  #vkokdcwdzm .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #vkokdcwdzm .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #vkokdcwdzm .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #vkokdcwdzm .gt_row_group_first td { border-top-width: 2px; }
#  #vkokdcwdzm .gt_row_group_first th { border-top-width: 2px; }
#  #vkokdcwdzm .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #vkokdcwdzm .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #vkokdcwdzm .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #vkokdcwdzm .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #vkokdcwdzm .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #vkokdcwdzm .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #vkokdcwdzm .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #vkokdcwdzm .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #vkokdcwdzm .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #vkokdcwdzm .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #vkokdcwdzm .gt_left { text-align: left; }
#  #vkokdcwdzm .gt_center { text-align: center; }
#  #vkokdcwdzm .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #vkokdcwdzm .gt_font_normal { font-weight: normal; }
#  #vkokdcwdzm .gt_font_bold { font-weight: bold; }
#  #vkokdcwdzm .gt_font_italic { font-style: italic; }
#  #vkokdcwdzm .gt_super { font-size: 65%; }
#  #vkokdcwdzm .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #vkokdcwdzm .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #vkokdcwdzm .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #vkokdcwdzm .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #vkokdcwdzm .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #vkokdcwdzm .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/NLP/index.qmd">Introduction to part 4: Natural Language Processing (NLP)</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/NLP/01_intro.qmd">Cleaning and structuring information in textual data</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #7 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/NLP/02_exoclean.qmd">Frequentist analysis using the bag-of-words approach: forces and limitations</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #7 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/NLP/03_embedding.qmd">Synthetizing textual information with embeddings</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #7 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Git

# %% [raw]
# <div id="rqqkkawbzo" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #rqqkkawbzo table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #rqqkkawbzo thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #rqqkkawbzo p { margin: 0; padding: 0; }
#  #rqqkkawbzo .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #rqqkkawbzo .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #rqqkkawbzo .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #rqqkkawbzo .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #rqqkkawbzo .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rqqkkawbzo .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #rqqkkawbzo .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rqqkkawbzo .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #rqqkkawbzo .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #rqqkkawbzo .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #rqqkkawbzo .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #rqqkkawbzo .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #rqqkkawbzo .gt_spanner_row { border-bottom-style: hidden; }
#  #rqqkkawbzo .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #rqqkkawbzo .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #rqqkkawbzo .gt_from_md> :first-child { margin-top: 0; }
#  #rqqkkawbzo .gt_from_md> :last-child { margin-bottom: 0; }
#  #rqqkkawbzo .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #rqqkkawbzo .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #rqqkkawbzo .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #rqqkkawbzo .gt_row_group_first td { border-top-width: 2px; }
#  #rqqkkawbzo .gt_row_group_first th { border-top-width: 2px; }
#  #rqqkkawbzo .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #rqqkkawbzo .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #rqqkkawbzo .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #rqqkkawbzo .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #rqqkkawbzo .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #rqqkkawbzo .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #rqqkkawbzo .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #rqqkkawbzo .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #rqqkkawbzo .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #rqqkkawbzo .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #rqqkkawbzo .gt_left { text-align: left; }
#  #rqqkkawbzo .gt_center { text-align: center; }
#  #rqqkkawbzo .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #rqqkkawbzo .gt_font_normal { font-weight: normal; }
#  #rqqkkawbzo .gt_font_bold { font-weight: bold; }
#  #rqqkkawbzo .gt_font_italic { font-style: italic; }
#  #rqqkkawbzo .gt_super { font-size: 65%; }
#  #rqqkkawbzo .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #rqqkkawbzo .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #rqqkkawbzo .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #rqqkkawbzo .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #rqqkkawbzo .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #rqqkkawbzo .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #3 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #3 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #3 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# # References
#
# Davenport, Thomas H, and DJ Patil. 2012. “Data Scientist, the Sexiest Job of the 21st Century.” *Harvard Business Review* 90 (5): 70–76. <https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century>.
#
# ———. 2022. “Is Data Scientist Still the Sexiest Job of the 21st Century?” *Harvard Business Review* 90.
#
# Galiana, Lino, and Olivier Lefebvre. 2026. “Qu’apportent Les métiers de La Data <span class="nocase">à</span> La Statistique Publique ?” *Courrier Des Statistiques*, no. 15: 95–116. <https://insee.hal.science/hal-05684911v1>.
#
# Kosmyna, Nataliya, Eugene Hauptmann, Ye Tong Yuan, Jessica Situ, Xian-Hao Liao, Ashly Vivian Beresnitzky, Iris Braunstein, and Pattie Maes. 2025. “Your Brain on ChatGPT: Accumulation of Cognitive Debt When Using an AI Assistant for Essay Writing Task.” *arXiv Preprint arXiv:2506.08872* 4: 206.
#
# Russell, Stuart J., and Peter Norvig. 2020. *Artificial Intelligence: A Modern Approach (4th Edition)*. Pearson. <http://aima.cs.berkeley.edu/>.
