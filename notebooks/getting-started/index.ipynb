# %% [markdown]
# # Introduction
#
# Lino Galiana
# 2026-09-06
#
#
# <div class="callout callout-style-default callout-tip callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Compétences à l’issue de ce chapitre
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# -   Comprendre pourquoi Python est devenu incontournable dans le domaine de la *data science* et du *data engineering*, notamment grâce à sa simplicité, sa lisibilité et son écosystème communautaire riche ;
# -   Identifier la manière dont Python peut vous assister dans les différentes étapes d’un projet de valorisation de données : structuration, exploration, modélisation, communication de résultats… ;
# -   Appréhender l’importance d’une démarche reproductible, rigoureuse et scientifique dans la conduite de projets de *data science* ou de *data engineering* et les moyens pour cela (*notebooks Jupyter*, open data, environnements standardisés…) ;
# -   Comprendre l’objet et les partis-pris pédagogiques du cours ainsi que son fil conducteur.
#
# </div>
# </div>
#
# # 1. Introduction
#
# Ce cours rassemble l’ensemble du contenu du cours
# ***Python pour la data science*** que je donne à l’[ENSAE](https://www.ensae.fr/courses/1425-python-pour-le-data-scientist) depuis 2020 et à l’[ENSAI](https://ensai.fr/) depuis 2026. Cela représente plus de 300 élèves qui suivent ce cours chaque année.
#
#
# <div class="callout callout-style-default callout-note callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Version internationale
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# L’année 2024 a permis l’arrivée progressive d’une version anglophone équivalente à
# la version française visant à servir de cours d’introduction à la *data science* pour les instituts statistiques européens
# suite à un [appel à projets européen](https://cros.ec.europa.eu/dashboard/aiml4os).
#
# </div>
# </div>
#
# Ce site ([pythonds.linogaliana.fr/](https://pythonds.linogaliana.fr)) est le point d’entrée principal du cours. Il rassemble l’ensemble des contenus faits en cours dans le cadre de travaux pratiques ou proposés en complément à des fins de formation en continue. Ce cours est *open source*
# et j’accueille avec plaisir les suggestions d’amélioration sur [`Github` ](https://github.com/linogaliana/python-datascientist) ou par le biais des commentaires en bas de chaque page.
#
# A partir de la rentrée 2026, ce cours connaît un changement important avec une division en deux partie, répartie sur deux semestres de scolarité, permettant d’approfondir chacune:
#
# -   Python pour la *data* au premier semestre correspondant à la première partie du cours consacrée à l’exploration de données ;
# -   Python pour le *ML* au deuxième semestre correspondant à la seconde partie du cours consacrée à la modélisation.
#
# `Python` étant un langage vivant et très dynamique, les pratiques évoluent et ce cours s’adapte en continu pour tenir compte de l’écosystème mouvant de la *data science*, en essayant néanmoins de distinguer les évolutions pérennes des pratiques des effets de mode.
#
# Si ce cours s’adresse en priorité à des étudiants en *data science*, il est suffisamment général pour intéresser de nombreux profils, étudiants comme professionels, issus de diverses formations académiques. Il est pensé pour être une introduction à la *data science* par le biais de Python.
#
#
# <div class="callout callout-style-default callout-tip callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Pour aller plus loin
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# Quelques éléments supplémentaires sont disponibles dans les [slides introductives](https://slidespython.linogaliana.fr/). Des éléments plus avancés sont présents dans un autre cours consacré à la mise en production de projets *data science* que je donne avec Romain Avouac en dernière année de l’ENSAE ([ensae-reproductibilite.github.io/website](https://ensae-reproductibilite.github.io/website)) et dont une variante sera donnée prochainement à l’ENSAI.
#
# </div>
# </div>

# %% [raw]
# <details>
# <summary><p>Dérouler les <em>slides</em> ou consulter celles-ci sur <a
# href="https://slidespython.linogaliana.fr/">plein écran</a>{target=</p></summary>
# <div class="sourceCode">
# <iframe class="sourceCode" src="https://slidespython.linogaliana.fr/"></iframe>
#
# </div>
# </details>

# %% [markdown]
# <div class="callout callout-style-default callout-note callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Architecture du site web
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# Ce cours présente des tutoriels et des exercices complets qui peuvent être lus depuis ce site ou édités et testés dans un environnement interactif de type *notebook* (voir [prochain chapitre](../../content/getting-started/01_environment.qmd) pour plus de détails).
#
# Chaque page est structurée sous la forme d’un problème concret et présente la démarche générique pour résoudre ce problème général. Tous les exemples s’appuient sur de l’*open data* et sont reproductibles.
#
# Vous pouvez naviguer dans l’architecture du site via la table des matières ou par les liens vers le contenu antérieur ou postérieur à la fin de chaque page. Certaines parties, notamment celle consacrée à la modélisation, proposent des exemples fil-rouge pour illustrer la démarche, et les différentes approches possibles d’un même problème, de manière
# plus extensive.
#
# </div>
# </div>
#
# # 2. Pourquoi faire du `Python`  ?
#
# `Python`, dont le logo assez reconnaissable prend la forme de ,
# est un langage qui a déjà plus de trente ans
# mais qui a connu, au cours de la décennie 2010, une
# nouvelle jeunesse du fait de l’engouement autour de
# la *data science*.
#
# `Python`, plus que tout autre
# langage informatique, réunit des communautés aussi
# diverses que des statisticiens, des développeurs,
# des gestionnaires
# d’applications ou d’infrastructures informatiques,
# des lycéens - `Python` est au programme du bac français
# depuis quelques années - ou des chercheurs
# dans des champs à la fois théoriques et appliqués.
#
# Contrairement à beaucoup de langages informatiques qui fédèrent
# une communauté assez homogène, `Python` est parvenu à réunir
# largement grâce à quelques principes centraux : la lisibilité
# du langage, la simplicité à utiliser des modules,
# la simplicité à l’associer à des langages plus performants
# pour certaines tâches données, l’énorme volume de documentation
# disponible en ligne…
# Être le deuxième meilleur langage pour réaliser telle ou telle
# tâche
# peut ainsi être une source de succès lorsque la concurrence ne dispose
# pas d’un éventail aussi large d’avantages.
#
# Le succès de `Python`, de par sa nature de
# langage couteau-suisse, est indissociable
# de l’émergence du profil du *data scientist*, profil
# capable de s’intégrer à différents niveaux dans la valorisation
# de données.
# Davenport et Patil (2012), dans la *Harvard Business Review*,
# ont ainsi pu parler du *“boulot le plus sexy du 21e siècle”*
# et ont pu, dix ans plus tard, faire un panorama complet de l’évolution
# des compétences attendues d’un *data scientist* dans
# la même revue (Davenport et Patil 2022). Ce ne sont d’ailleurs pas que les
# *data scientists* qui ont vocation à pratiquer `Python` ; dans le halo
# des emplois autour de la donnée (*data scientist*, *data engineer*, *ML engineer*…),
# `Python` fait office de tour de Babel permettant la communication entre ces
# différents profils interdépendants[1].
#
# La richesse de `Python` permet de l’utiliser dans toutes les phases du traitement de la donnée, de sa récupération et structuration à partir de
# sources diverses à sa valorisation.
# Par le prisme de la *data science*, nous verrons que `Python` est un très bon candidat pour assister les *data scientists* dans tous les aspects du travail quotidien leur permettant de tirer de la valeur de gisements hétérogènes de données. Ce cours a néanmoins l’ambition, peut-être illusoire, d’être plus qu’un énième cours d’introduction au langage `Python`: il s’agit plutôt d’un cours d’introduction à la *data science* s’appuyant sur `Python`. En fait, apprendre `Python` est un prétexte pour apprendre à avoir les bons réflexes quand on est confronté à un jeu de données.
#
# Ce cours introduit différents outils qui permettent de mettre en relation, grâce à `Python`, des données à des concepts théoriques issus de la statistique ou des sciences économiques et sociales. Néanmoins, ce cours va au-delà d’une simple introduction au langage et revient régulièrement sur les apports, mais aussi les limites, du langage pour répondre à des besoins opérationnels ou scientifiques.
#
# # 3. Pourquoi faire du `Python`  pour l’analyse de données ?
#
# Cette question est un peu différente car si `Python` est un langage commun pour découvrir la programmation informatique du fait de sa simplicité d’usage, comment se fait-il qu’il se soit imposé comme le langage dominant dans l’écosystème de la *data* et de l’IA ?
#
# `Python` est d’abord connu, dans le monde de la *data science*, pour avoir fourni très tôt les outils utiles à l’entraînement d’algorithmes de *machine learning*, avant même que cette approche devienne incontournable. Certes,
# le succès de [`Scikit Learn`](https://scikit-learn.org/stable/), de [`Tensorflow`](https://www.tensorflow.org/) ou plus récemment de [`PyTorch`](https://pytorch.org/) dans la communauté de la *data science* ont beaucoup contribué à l’adoption de `Python`[2]. Cependant,
# résumer `Python` à quelques librairies de *machine learning*
# serait réducteur tant il s’agit
# d’un véritable couteau-suisse pour les *data scientists*,
# les *social scientists*, les économistes ou plus généralement pour les praticiens de la donnée quelque soit leur champ d’application. La *success story* de `Python`
# n’est pas seulement le fait d’avoir proposé des librairies de *machine learning* à un moment adéquat: ce
# langage dispose de réels atouts pour de nouveaux praticiens de la donnée.
#
# L’intérêt de `Python` est son rôle central dans un
# écosystème plus large autour d’outils puissants, flexibles et *open-source*. Il appartient, comme le langage , à cette classe de langages pouvant servir au quotidien pour des tâches très diversifiées. Dans de nombreux domaines explorés dans ce cours, `Python` est, de loin, le langage informatique proposant l’écosystème le plus complet et le plus simple d’accès. Contrairement à d’autres langages très populaires, notamment `JavaScript` ou `Rust`, la courbe d’appentissage de `Python` est très légère et on peut rapidement être opérationnel et produire du code de qualité, si on a les bons réflexes (que ce cours, ainsi que celui de [mise en production](https://ensae-reproductibilite.github.io/), ambitionnent de donner).
#
# En plus des projets d’IA (<a href="#nte-ia" class="quarto-xref">Note 3.1</a>), `Python` est
# incontournable dès lors qu’on désire récupérer des données par le biais d’API ou de *web scraping*[3], deux approches que nous explorerons dans la première partie du cours. Dans les domaines de l’analyse de données tabulaires[4], de la publication de contenu web ou de la production de graphiques, `Python` présente un écosystème
# de plus en plus similaire à du fait de l’investissement croissant de [`Posit`](https://posit.co/) et sa traduction en `Python` des librairies qui ont fait le succès de dans le domaine de l’analyse de données ([ggplot](https://ggplot2.tidyverse.org/) notamment)[5].
#
# Les **données tabulaires** sont des données structurées, organisées, comme leur nom l’indique, sous forme de tableau permettant de mettre en correspondance des observations avec des variables. Cette structuration se distingue d’autres types de données plus complexes: textes libres, images, sons, vidéos…
#
# > **Note 3.1**
# >
# > <div class="callout callout-style-default callout-note callout-titled" id="nte-ia">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Pourquoi parler si peu d’IA dans un cours de Python    ?
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > Bien qu’une partie conséquente de ce cours évoque les problématiques de *machine learning* et d’algorithmie, je rechigne généralement à rentrer dans la mode, particulièrement forte depuis fin 2022 et la sortie de `ChatGPT`, de tout dénommer IA.
# >
# > En premier lieu car le terme est souvent mal défini, galvaudé et instrumentalisé par des acteurs qui profitent de sa charge symbolique forte, lié à notre imaginaire de la science fiction, pour vendre un produit “miracle” ou au contraire activer nos peurs.
# >
# > Mais aussi car ce terme recouvre énormément de méthodes potentielles si on accepte une définition large. Les parties modélisation et NLP de ce cours, celles les plus proches du sujet IA, se concentrent sur les méthodes d’apprentissage. Si on reprend les définitions suivantes Russell et Norvig (2020) ou de l’[IA Act Européen](https://artificialintelligenceact.eu/fr/article/3/), on peut faire rentrer beaucoup plus que ces méthodes dans le concept d’intelligence artificielle:
# >
# > > « L’étude des agents \[intelligents\] qui reçoivent des perceptions de l’environnement et agissent. Chacun de ces agents est mis en oeuvre par une fonction qui associe les perceptions aux actions, et nous couvrons différentes manières de de représenter ces fonctions, telles que les systèmes de production, les agents réactifs, les planificateurs logiques, les réseaux de neurones et les systèmes de gestion de l’information et les systèmes de théorie de la décision »
# > >
# > > Russell et Norvig (2020)
# >
# > > « Système basé sur une machine qui est conçu pour fonctionner avec différents niveaux d’autonomie et qui peut faire preuve d’adaptabilité après son déploiement, et qui, pour des objectifs explicites ou implicites, déduit, à partir des données qu’il reçoit, comment générer des résultats tels que des prédictions, du contenu, des recommandations ou des décisions qui peuvent influencer des environnements physiques ou virtuels »
# > >
# > > [AI Act européen](https://artificialintelligenceact.eu/fr/article/3/)
# >
# > Pour en apprendre plus sur ce sujet, voici une présentation que j’ai faite sur le sujet de l’IA en 2024:
# >
# > <details>
# > <summary><p>Dérouler les <em>slides</em> ou consulter celles-ci sur <a
# > href="https://linogaliana.github.io/20241015-prez-ia-masa/#/title-slide/">plein
# > écran</a>{target=</p></summary>
# > <div class="sourceCode">
# > <iframe class="sourceCode" src="https://linogaliana.github.io/20241015-prez-ia-masa/#/title-slide/"></iframe>
# >
# > </div>
# > </details>
# >
# > Enfin, la question est également pédagogique. Quand on parle d’IA depuis 2023, on pense à l’IA générative. Je pense que pour comprendre le fonctionnement de cette approche, radicalement différent d’autres paradigmes, et être capable de mettre en oeuvre des projets d’IA générative porteurs de valeur, il faut avoir des notions sur les apports et les limites de l’approche scientifique du *machine learning*. Sinon, on se retrouve à construire des usines à gaz pour des besoins simples ou à être incapables d’évaluer l’apport d’une approche générative par rapport à d’autres approches. Ce cours étant introductif, j’ai donc choisi de me concentrer sur le *machine learning* et du NLP basique, là encore à un niveau assez introductifs mais néanmoins déjà un peu creusés, et laisser aux curieux le soin de s’autoformer sur les sujets genIA.
# >
# > </div>
# > </div>
#
# # 4. Pourquoi apprendre `Python` quand il existe des IA génératrices de code ?
#
# Les assistants de code, notamment `Claude` et `ChatGPT`, ont changé à jamais le développement de code. La vitesse des changements est assez ahurissante.
#
# Ces outils font maintenant parti des outils quotidiens des *data scientists* et offrent beaucoup de confort car ils peuvent, à l’aide d’instructions plus ou moins claires, générer du code `Python`. Et ces IA ayant étaient entraînées à partir de l’ensemble du code présent sur internet, et parfois spécialisées à répondre à des problèmes de développement, elles aident beaucoup.
#
# L’intégration d’outils de *vibe coding* dans les IDE (notamment `Claude Code`) a encore accéléré ce processus et représente un réel défi pour le monde éducatif.
#
# *Puisque maintenant les IA génèrent du code, pourquoi continuer à apprendre à coder ?*
#
# ## 4.1 Car coder, c’est résoudre un problème d’ingénierie
#
# Car coder ce n’est pas juste produire des lignes de code, c’est se confronter à un problème, adopter une stratégie par étape pour y répondre, réfléchir à plusieurs solutions possibles et choisir la meilleure en arbitrant entre plusieurs objectifs (vitesse, simplicité, etc.), tester et corriger, etc. Le code est un outil au service d’un problème d’ingenieurie. Les IA savent très bien coder, elles savent relier un problème à des ressources sur lesquelles elles ont appris et savent bien transposer un problème rencontré dans un autre langage à `Python`.
#
# Mais encore faut-il savoir formuler le problème, savoir juger de la qualité de la réponse du LLM, être capable de remettre en question la proposition de l’assistant pour corriger une erreur ou obtenir une réponse plus satisfaisante. Les LLM sont une recherche *google* très (très) raffinée: si vous n’avez pas les bons mots clés pour faire une recherche Google, votre recherche sera décevante. Il en va de même avec les LLM même si l’aspect conversationnel en langage naturel réduit la barrière à l’entrée.
#
# Le code n’est pas une fin en soi, mais un outil au service d’un raisonnement structuré, visant à résoudre un problème concret.
#
# La confrontation à un jeu de données, à la recherche de réponse non évidentes, va soulever plus ou moins de questions scientifiques et d’ingénierie. Comme un ingénieur qui conçoit un pont, qui va chercher à satisfaire le besoin de traversée avec les connaissances scientifiques et les matériaux disponibles, le *data scientist* part d’un objectif opérationnel (construire un algorithme de sélection, mesurer l’impact d’un lancement produit, prédire une évolution de ventes) pour le formuler de manière exploitable. Cela implique de traduire des concepts scientifiques ou *business* en questions analytiques, puis de décomposer le problème en étapes logiques, chacune traduites en instructions que la machine peut exécuter.
#
# Dans ce cadre, un LLM peut jouer un rôle d’assistant, mais seulement si le problème est bien posé. Si les étapes sont floues ou mal définies, la réponse du modèle sera approximative, voire inutile. Certes la frontière est sans cesse repoussée grâce aux capacités de raisonnement accrues des modèles mais ces outils restent limités. Sur une tâche standard, le résultat pourra sembler correct, mais sur une question plus spécifique, il faudra souvent affiner, reformuler, itérer… et parfois ne jamais obtenir de réponse satisfaisante. Non pas parce que le modèle est mauvais, mais parce que l’ingénierie du problème en amont fait toute la différence[6].
#
# ## 4.2 Car coder, c’est réflechir
#
# De plus, si on ne prend pas le temps, pendant les études, de se confronter à ces problèmes, d’apprendre, quand aura-t-on le temps de le faire ? Bien que nous ayons encore peu de recul sur ce sujet, la recherche en sciences cognitives commence à accumuler des résultats qui montrent un effet négatif de l’utilisation de l’IA sur le cerveau (voir le concept de “dette cognitive” chez Kosmyna et al. (2025)).
#
# Il ne s’agit pas de verser dans la nostalgie de l’époque dorée où on pouvait passer plusieurs heures à se casser la tête sur un problème de code qu’une IA peut maintenant résoudre en quelques minutes voire secondes. J’utilise moi-même quotidiennement des IA génératives pour assister la génération de code ou la création de contenu (par exemple pour la traduction automatique de ce cours en Anglais). Cependant, il ne faut pas oublier que l’objectif est de pouvoir faire plus de *deep work* (et y prendre plaisir!) et non devenir uniquement une machine aliénée, condamnée à cliquer sur le bouton *“Yes”* le plus vite possible lorsque Claude demande une autorisation. C’est difficile puisque les outils disponibles tendent à nous rendre dépendants d’eux. La meilleure manière d’éviter d’être captif de ces outils reste d’acquérir, et de continuer à contruire tout au long de sa vie professionnelle, des compétences générales: c’est l’ambition de ce cours appliqué de *data science*.
#
# ## 4.3 Car coder, c’est actualiser, encore et toujours, ses connaissances
#
# Une dernière raison pour laquelle se contenter d’une IA de code sans recul critique est que ces dernières sont forcément en retard par rapport aux usages puisqu’elles ont été entraînées sur des données passées. L’écosystème `Python` est très dynamique et, même si les IA des principaux fournisseurs de services sont fréquemment réentrainées et peuvent maintenant accéder à internet pour rafraichir leurs connaissances, certaines librairies peuvent rapidement s’imposer dans leur domaine.
#
# Par exemple, l’année dernière, [`uv`](https://docs.astral.sh/uv/) a connu une adoption rapide, comme [`ruff`](https://docs.astral.sh/ruff/) l’année d’avant. L’existence d’IA génératives ne dispense donc pas, comme avant, d’avoir une veille technique active et d’être vigilant sur l’évolution des pratiques.
#
# # 5. Objectifs du cours
#
# ## 5.1 Initier à la démarche de la *data science*
#
# Ce cours s’adresse aux praticiens de la *data science*,
# discipline entendue ici au sens large comme la **combinaison de techniques issues des mathématiques, de la statistique et de l’informatique pour produire de la connaissance utile à partir de données**.
#
# Comme la *data science* n’est pas uniquement une discipline scientique mais vise également à fournir un ensemble d’outils pour répondre à des objectifs opérationnels, l’apprentissage du principal outil nécessaire à l’acquisition de connaissances en *data science*, à savoir le langage `Python`, est également
# l’occasion d’évoquer la démarche scientifique rigoureuse à adopter face à des données. Ce cours a pour objectif de présenter la démarche face à un jeu de données, les problèmes rencontrés, les solutions pour les surmonter et les implications que ces dernières peuvent avoir. Il ne s’agit donc pas que d’un cours sur un outil technique, désincarné de problématiques scientifiques.
#
#
# <div class="callout callout-style-default callout-tip callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Faut-il avoir un background en mathématiques pour ce cours ?
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# Ce cours présuppose qu’on désire faire un usage de `Python` intense en données dans un cadre statistique rigoureux. Il ne revient que de manière secondaire sur les fondements statistiques ou algorithmiques derrière certaines des techniques évoquées, souvent l’objet d’enseignements dédiés, notamment à l’ENSAE.
#
# Ne pas connaître ces notions n’empêche ainsi pas de comprendre
# le contenu de ce site *web* car les concepts plus avancés sont généralement présentés à part, dans des encadrés dédiés. La facilité d’usage de `Python` évite de devoir programmer soi-même un modèle, ce qui rend possible l’application de modèles dont on n’est pas expert. La connaissance des modèles sera plutôt nécessaire dans l’interprétation des résultats.
#
# Pour autant, même s’il est relativement facile d’utiliser des modèles complexes avec `Python`, il est fort utile d’avoir du recul sur ceux-ci avant de se lancer dans une démarche de modélisation. Il s’agit de l’une des raisons pour lesquelles la modélisation arrive si tardivement dans ce cours: en plus de faire appel à des concepts statistiques avancés, il est nécessaire, pour produire une modélisation pertinente, d’avoir appréhendé les faits stylisés dans nos données. Bien comprendre la structure des données et leur adéquation avec les hypothèses d’un modèle est indispensable pour construire une modélisation de qualité.
#
# </div>
# </div>
#
# ## 5.2 Reproductibilité
#
# Ce cours donne une place centrale à la notion de reproductibilité. Cette exigence se traduit de diverses
# manières dans cet enseignement, en premier lieu en permettant que tous les exemples et exercices de ce cours soient testés par le biais de *notebooks* `Jupyter`.
#
# Un *notebook* est un environnement interactif qui permet d’écrire et d’exécuter du code en direct. Il combine, dans un seul document, du texte, du code qui peut être exécuté et dont les sorties s’affichent après calculs. C’est extrêmement pratique pour l’apprentissage du langage `Python`.
#
# Pour plus de détails, consultez la [documentation officielle de Jupyter](https://jupyter.org/documentation).
#
# L’ensemble du contenu du site *web* est reproductible dans des environnements informatiques divers. Il est bien sûr possible de copier-coller les morceaux de code présents dans ce site, grâce au bouton présent au dessus
# des exemples de code:
#
# [1] Voir Galiana et Lefebvre (2026) pour plus d’éléments de contexte sur l’évolution des emplois de la *data*.
#
# [2] [`Scikit Learn`](https://scikit-learn.org/stable/) est une librairie développée par les laboratoires de recherche publique français de l’INRIA depuis 2007. C’est un projet *open source* depuis le début. Le projet est désormais maintenu par [`:probabl.`](https://probabl.ai/), une *startup* dédiée à la gestion du projet *open source* `Scikit` et tout son écosystème associé qui rassemble une partie des équipes de recherche de l’INRIA qui a a participé au développement de l’écosystème incontournable du *machine learning*.
#
# [`Tensorflow`](https://www.tensorflow.org/) est une librairie initialement développée par Google pour leurs besoins internes, celle-ci a été rendue publique en 2015. Bien que moins de moins en moins utilisée, notamment du fait de la popularité de `PyTorch`, cette librairie a eu une influence importante dans les années 2010 en favorisant l’usage des réseaux de neurone dans la recherche ou pour l’exploitation à des fins opérationnelles.
#
# [`PyTorch`](https://pytorch.org/) est une librairie développée par Meta depuis 2018 et rattachée depuis 2022 à la [*PyTorch foundation*](https://pytorch.org/foundation). Il s’agit aujourd’hui du principal *framework* pour entraîner des réseaux de neurones.
#
# [3] Dans ces deux domaines, le concurrent le plus sérieux pour `Python`
# est `Javascript`. Néanmoins, la communauté autour de ce dernier langage est plus orientée
# autour des problématiques de développement web que de *data science*.
#
# [4] Dans le domaine des données
# non structurées, `Python` est le langage d’analyse hégémonique. Dans le domaine des données tabulaires, l’avantage compétitif de `Python` est moindre, notamment par rapport à , mais ces deux langages proposent un noyau de fonctionnalités assez similaires. Nous aurons l’occasion de régulièrement faire le parallèle entre ces deux langages lors des chapitres consacrés à la librairie `Pandas`.
#
# Néanmoins, il ne s’agit pas, par ces éléments, de rentrer dans la guéguerre stérile vs `Python`.
#
# Ces deux langages ayant beaucoup plus de points de convergence que de divergence, il est très simple de transposer les bonnes pratiques d’un langage à l’autre. Il s’agit d’un point qui est développé plus amplement dans le cours plus avancé que je donne avec Romain Avouac en dernière année d’ENSAE : [ensae-reproductibilite.github.io/website](https://ensae-reproductibilite.github.io/website).
#
# [5] A terme, les *data scientists* et chercheurs en sciences sociales ou en économie utiliseront de manière presque indifférente, et en alternance, ou `Python`. Ce cours présentera ainsi régulièrement des analogies avec pour aider les
# personnes découvrant `Python`, mais connaissant déjà bien , à mieux comprendre certains messages.
#
# [6] Il n’est pas inutile sur ce sujet de lire le *post* de Thomas Wolf (CSO de `HuggingFace`) [“The Einstein AI model”](https://thomwolf.io/blog/scientific-ai.html). Même si le *post* évoque principalement les innovations de rupture en mettant quelque peu de côté les innovations marginales, il est intéressant de comprendre que les LLM, en dépit des grandes annonces prophétiques faites par les gourous de la tech, restent des outils qui certes ont de bonnes performances sur des tests standardisés mais restent des assistants, pour l’heure.

# %%
x = "Essayez de me copier-coller"

# %% [markdown]
# Néanmoins, comme ce site présente de nombreux exemples, les allers et retours entre un environnement de test de `Python` et celui-ci pourraient être pénibles. Chaque chapitre est donc facilement récupérable sous forme de *notebook* `Jupyter` grâce à des boutons au début de chaque page. Voici, par exemple, ces boutons pour le premier chapitre consacré à `Pandas` :
#
# <div class="badge-container"><a href="https://github.com/linogaliana/python-datascientist-notebooks/blob/main/notebooks/manipulation/02_pandas_intro.ipynb" class="badge" target="_blank" rel="noopener"><img src="https://img.shields.io/static/v1?logo=github&label=&message=View%20on%20GitHub&color=181717" alt="View on GitHub"></a>
# <a href="https://datalab.sspcloud.fr/launcher/ide/vscode-python?autoLaunch=true&name=«02_pandas_intro»&init.personalInit=«https%3A%2F%2Fraw.githubusercontent.com%2Flinogaliana%2Fpython-datascientist%2Fmain%2Fsspcloud%2Finit-vscode.sh»&init.personalInitArgs=«manipulation%2002_pandas_intro»" class="badge" target="_blank" rel="noopener"><img src="https://custom-icon-badges.demolab.com/badge/SSP%20Cloud-Lancer_avec_VSCode-blue?logo=vsc&logoColor=white" alt="Onyxia"></a>
# <a href="https://colab.research.google.com/github/linogaliana/python-datascientist-notebooks-colab//blob/main//notebooks/manipulation/02_pandas_intro.ipynb" class="badge" target="_blank" rel="noopener"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
# <a href="https://codespaces.new/linogaliana/python-datascientist-notebooks?quickstart=1&ref=main" class="badge" target="_blank" rel="noopener"><img src="https://github.com/codespaces/badge.svg" alt="Open in GitHub Codespaces"></a><br></div>
#
# Les recommandations concernant les environnements à privilégier pour utiliser ces notebooks sont reportées au prochain chapitre.
#
# L’exigence de reproductibilité se manifeste également
# dans le choix des exemples pris pour ce cours. L’ensemble du contenu de ce site s’appuie sur des données ouvertes, qu’il s’agisse de données françaises (principalement issues de la plateforme centralisatrice [`data.gouv`](https://www.data.gouv.fr) ou du site *web* de l’[Insee](https://www.insee.fr)) ou de données américaines. Les résultats sont donc reproductibles pour quelqu’un disposant d’un environnement identique[1].
#
#
# <div class="callout callout-style-default callout-note callout-titled">
# <div class="callout-header d-flex align-content-center">
# <div class="callout-icon-container">
# <i class="callout-icon"></i>
# </div>
# <div class="callout-title-container flex-fill">
# Note
# </div>
# </div>
# <div class="callout-body-container callout-body">
#
# Des chercheurs américains ont pu parler de crise de la reproductibilité dans le domaine du *machine learning* (Kapoor et Narayanan 2022). Les dérives de l’écosystème de
# la publication scientifique et les enjeux économiques derrière les publications académiques dans le domaine du *machine learning* ont une place privilégiée parmi les facteurs pouvant l’expliquer.
#
# Néanmoins, l’enseignement universitaire porte également une responsabilité dans ce domaine. Les étudiants et chercheurs ne sont pas formés à ces sujets et s’ils n’adoptent pas cette exigence tôt dans leur parcours, ils n’y seront plus forcément incités ultérieurement. Pour cette raison, en plus de former à `Python` et à la *data science*, ce cours introduit à l’usage du logiciel de contrôle de version `Git` dans une partie dédiée.
#
# Tous les projets des élèves doivent être *open source*, ce qui est l’une des meilleures manières, pour un enseignant, de trouver une consigne pour que les élèves produisent un code de qualité.
#
# </div>
# </div>
#
# ## 5.3 Évaluation
#
# Les élèves de l’ENSAE et l’ENSAI valident le cours grâce à
# un projet approfondi. Les éléments relatifs à l’évaluation du cours, ainsi qu’une liste des projets déjà effectués, sont disponibles dans la section [Évaluation](../../content/annexes/evaluation).
#
# # 6. Plan du cours
#
# Ce cours est une introduction aux enjeux de la *data science* à
# travers l’apprentissage du langage `Python`. Comme le terme *“data science”*
# l’indique, une partie importante de ce cours est consacrée au travail sur les
# données: récupération, structuration, exploration, mise en relation.
#
# C’est l’objet de la première partie du cours [“Manipuler des données”](../../content/manipulation/index.qmd) qui sert de fondement au reste du cours. Malheureusement, de nombreuses formations en *data science*, statistiques appliquées ou sciences économiques et sociales, font l’impasse sur cette part du travail des *data scientists* - qu’on appelle parfois [“data wrangling”](https://en.wikipedia.org/wiki/Data_wrangling) ou [*“feature engineering”*](https://en.wikipedia.org/wiki/Feature_engineering) - qui, en plus de représenter une part importante du temps de travail des *data scientists*, est indispensable pour construire un modèle pertinent.
#
# L’objectif de cette partie est d’illustrer les enjeux liés à la récupération de plusieurs types de sources de données et à leur exploitation par le biais de `Python`. Les exemples seront diversifiés, pour illustrer la richesse des données qui peuvent être analysées avec `Python`: statistiques d’émissions communales de $CO_2$ en France, données de transactions immobilières, diagnostics énergétiques des logements, données de fréquentation des stations vélib…
#
# La deuxième partie est consacrée à la production de visualisations avec `Python`. Après avoir récupéré et nettoyé des données, on désire généralement synthétiser celles-ci par le biais de tableaux, de productions graphiques ou de cartes. Cette partie est une introduction rapide à ce sujet ([“Communiquer avec `Python`”](../../content/visualisation/index.qmd)). Assez introductive, l’objectif de cette partie est surtout de donner quelques notions qui sont consolidées par la suite.
#
# La troisième partie est consacrée à la modélisation à travers l’exemple fil rouge de la science électorale ([“Modéliser avec `Python`”](../../content/modelisation/index.qmd)). L’objectif de cette partie est d’illustrer la démarche scientifique du *machine learning*, les choix méthodologiques et techniques afférents et ouvrir vers les enjeux suivants qui seront évoqués dans la suite du cursus universitaire.
#
# La quatrième partie du cours fait un pas de côté pour se consacrer aux enjeux spécifiques liés à l’exploitation des données textuelles. Il s’agit du chapitre d’[“Introduction au *Natural Language Processing (NLP)”* avec `Python`”](../../content/NLP/index.qmd). Ce champ de recherche étant particulièrement actif, il ne s’agit que d’une introduction au sujet. Pour aller plus loin, se référer à Russell et Norvig (2020), chapitre 24.
#
# Ce chapitre propose aussi une partie consacrée au contrôle de version avec le logiciel `Git` ([Découvrir `Git`](../../content/git/index.qmd)). Pourquoi proposer ce contenu dans le cadre d’un cours de `Python` ? Car apprendre `Git` permettra de produire de meilleurs codes `Python`, de les échanger, voire même de les tester dans des environnements reproductibles ou de mettre à disposition les résultats en ligne (c’est une utilisation plus avancée, objet du cours de [mise en production](https://ensae-reproductibilite.github.io/)). Ce pas de côté dans l’apprentissage de `Python` est très utile, *a fortiori* dans un monde où [`Github`](https://github.com/) sert de vitrine et où les entreprises et administrations exigent, à juste titre, que leurs *data scientists* sachent faire du `Git`.
#
# De manière plus détaillée, voici le plan du cours:
#
# ### Introduction
#
# [1] Le fait d’ouvrir les chapitres sous la forme de *notebooks* dans des environnements standardisés, ce qui sera proposé à partir du prochain chapitre, permet d’assurer que vous disposiez d’un environnement contrôlé. Les installations personnelles de `Python` ont toutes les chances d’avoir subies des bidouillages modifiant votre environnement et pouvant provoquer des erreurs inattendues et difficiles à comprendre: ce n’est donc pas un usage recommandé pour ce cours. Comme vous pourrez le découvrir dans le prochain chapitre, les environnements *cloud* offrent un confort en ce qui concerne la standardisation des environnements.

# %% [raw]
# <div id="ghmihsqnfj" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #ghmihsqnfj table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ghmihsqnfj thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ghmihsqnfj p { margin: 0; padding: 0; }
#  #ghmihsqnfj .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #ghmihsqnfj .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ghmihsqnfj .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #ghmihsqnfj .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #ghmihsqnfj .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ghmihsqnfj .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ghmihsqnfj .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ghmihsqnfj .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ghmihsqnfj .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ghmihsqnfj .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ghmihsqnfj .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ghmihsqnfj .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ghmihsqnfj .gt_spanner_row { border-bottom-style: hidden; }
#  #ghmihsqnfj .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ghmihsqnfj .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #ghmihsqnfj .gt_from_md> :first-child { margin-top: 0; }
#  #ghmihsqnfj .gt_from_md> :last-child { margin-bottom: 0; }
#  #ghmihsqnfj .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #ghmihsqnfj .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #ghmihsqnfj .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ghmihsqnfj .gt_row_group_first td { border-top-width: 2px; }
#  #ghmihsqnfj .gt_row_group_first th { border-top-width: 2px; }
#  #ghmihsqnfj .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #ghmihsqnfj .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #ghmihsqnfj .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #ghmihsqnfj .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #ghmihsqnfj .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ghmihsqnfj .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #ghmihsqnfj .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #ghmihsqnfj .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #ghmihsqnfj .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ghmihsqnfj .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ghmihsqnfj .gt_left { text-align: left; }
#  #ghmihsqnfj .gt_center { text-align: center; }
#  #ghmihsqnfj .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ghmihsqnfj .gt_font_normal { font-weight: normal; }
#  #ghmihsqnfj .gt_font_bold { font-weight: bold; }
#  #ghmihsqnfj .gt_font_italic { font-style: italic; }
#  #ghmihsqnfj .gt_super { font-size: 65%; }
#  #ghmihsqnfj .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ghmihsqnfj .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #ghmihsqnfj .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ghmihsqnfj .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ghmihsqnfj .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ghmihsqnfj .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/getting-started/index.qmd">Introduction</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/getting-started/01_environment.qmd">Avoir un environnement Python fonctionnel pour la data science</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/getting-started/02_data_analysis.qmd">Démarche à adopter face à un jeu de données</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/getting-started/03_revisions.qmd">Quelques exercices de rappels pour se remettre en selle</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Manipuler des données

# %% [raw]
# <div id="hyuqtdokps" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #hyuqtdokps table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #hyuqtdokps thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #hyuqtdokps p { margin: 0; padding: 0; }
#  #hyuqtdokps .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #hyuqtdokps .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #hyuqtdokps .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #hyuqtdokps .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #hyuqtdokps .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hyuqtdokps .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hyuqtdokps .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hyuqtdokps .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #hyuqtdokps .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #hyuqtdokps .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #hyuqtdokps .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #hyuqtdokps .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #hyuqtdokps .gt_spanner_row { border-bottom-style: hidden; }
#  #hyuqtdokps .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #hyuqtdokps .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #hyuqtdokps .gt_from_md> :first-child { margin-top: 0; }
#  #hyuqtdokps .gt_from_md> :last-child { margin-bottom: 0; }
#  #hyuqtdokps .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #hyuqtdokps .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #hyuqtdokps .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #hyuqtdokps .gt_row_group_first td { border-top-width: 2px; }
#  #hyuqtdokps .gt_row_group_first th { border-top-width: 2px; }
#  #hyuqtdokps .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #hyuqtdokps .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #hyuqtdokps .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #hyuqtdokps .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #hyuqtdokps .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hyuqtdokps .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #hyuqtdokps .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #hyuqtdokps .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #hyuqtdokps .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #hyuqtdokps .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #hyuqtdokps .gt_left { text-align: left; }
#  #hyuqtdokps .gt_center { text-align: center; }
#  #hyuqtdokps .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #hyuqtdokps .gt_font_normal { font-weight: normal; }
#  #hyuqtdokps .gt_font_bold { font-weight: bold; }
#  #hyuqtdokps .gt_font_italic { font-style: italic; }
#  #hyuqtdokps .gt_super { font-size: 65%; }
#  #hyuqtdokps .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #hyuqtdokps .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #hyuqtdokps .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #hyuqtdokps .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #hyuqtdokps .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #hyuqtdokps .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/index.qmd">Introduction à la partie 1: manipuler des données</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/01_numpy.qmd">Numpy, la brique de base de la data science</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #1 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/02_pandas_intro.qmd">Introduction à Pandas</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #2 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/02_pandas_joins.qmd">Associer des données avec Pandas : les jointures</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #2 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/02_pandas_stats.qmd">Manipuler des données avec Pandas : statistiques et restructuration</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #2 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/02_pandas_beyond.qmd">Pandas : limites et écosystèmes alternatifs</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #2 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/03_geopandas_intro.qmd">Introduction aux données spatiales avec Geopandas</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #4 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/04a_webscraping_TP.qmd">Web scraping avec Python</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/04c_API_TP.qmd">Récupérer des données avec des API depuis Python</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #4 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/04b_regex_TP.qmd">Maîtriser les expressions régulières</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/manipulation/05_parquet_s3.qmd">Les nouveaux modes d'accès aux données : le format Parquet et les données sur le cloud</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Communiquer

# %% [raw]
# <div id="wrxptxyedb" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #wrxptxyedb table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #wrxptxyedb thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #wrxptxyedb p { margin: 0; padding: 0; }
#  #wrxptxyedb .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #wrxptxyedb .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #wrxptxyedb .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #wrxptxyedb .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #wrxptxyedb .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wrxptxyedb .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #wrxptxyedb .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wrxptxyedb .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #wrxptxyedb .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #wrxptxyedb .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #wrxptxyedb .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #wrxptxyedb .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #wrxptxyedb .gt_spanner_row { border-bottom-style: hidden; }
#  #wrxptxyedb .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #wrxptxyedb .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #wrxptxyedb .gt_from_md> :first-child { margin-top: 0; }
#  #wrxptxyedb .gt_from_md> :last-child { margin-bottom: 0; }
#  #wrxptxyedb .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #wrxptxyedb .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #wrxptxyedb .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #wrxptxyedb .gt_row_group_first td { border-top-width: 2px; }
#  #wrxptxyedb .gt_row_group_first th { border-top-width: 2px; }
#  #wrxptxyedb .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #wrxptxyedb .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #wrxptxyedb .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #wrxptxyedb .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #wrxptxyedb .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #wrxptxyedb .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #wrxptxyedb .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #wrxptxyedb .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #wrxptxyedb .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #wrxptxyedb .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #wrxptxyedb .gt_left { text-align: left; }
#  #wrxptxyedb .gt_center { text-align: center; }
#  #wrxptxyedb .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #wrxptxyedb .gt_font_normal { font-weight: normal; }
#  #wrxptxyedb .gt_font_bold { font-weight: bold; }
#  #wrxptxyedb .gt_font_italic { font-style: italic; }
#  #wrxptxyedb .gt_super { font-size: 65%; }
#  #wrxptxyedb .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #wrxptxyedb .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #wrxptxyedb .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #wrxptxyedb .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #wrxptxyedb .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #wrxptxyedb .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/visualisation/index.qmd">Introduction à la partie 2: communiquer à partir de données</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/visualisation/matplotlib.qmd">Construire des graphiques avec Python</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/visualisation/maps.qmd">Introduction à la cartographie avec Python</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Modéliser

# %% [raw]
# <div id="tmfhahxixb" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #tmfhahxixb table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #tmfhahxixb thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #tmfhahxixb p { margin: 0; padding: 0; }
#  #tmfhahxixb .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #tmfhahxixb .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #tmfhahxixb .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #tmfhahxixb .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #tmfhahxixb .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #tmfhahxixb .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #tmfhahxixb .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #tmfhahxixb .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #tmfhahxixb .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #tmfhahxixb .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #tmfhahxixb .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #tmfhahxixb .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #tmfhahxixb .gt_spanner_row { border-bottom-style: hidden; }
#  #tmfhahxixb .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #tmfhahxixb .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #tmfhahxixb .gt_from_md> :first-child { margin-top: 0; }
#  #tmfhahxixb .gt_from_md> :last-child { margin-bottom: 0; }
#  #tmfhahxixb .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #tmfhahxixb .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #tmfhahxixb .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #tmfhahxixb .gt_row_group_first td { border-top-width: 2px; }
#  #tmfhahxixb .gt_row_group_first th { border-top-width: 2px; }
#  #tmfhahxixb .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #tmfhahxixb .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #tmfhahxixb .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #tmfhahxixb .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #tmfhahxixb .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #tmfhahxixb .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #tmfhahxixb .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #tmfhahxixb .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #tmfhahxixb .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #tmfhahxixb .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #tmfhahxixb .gt_left { text-align: left; }
#  #tmfhahxixb .gt_center { text-align: center; }
#  #tmfhahxixb .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #tmfhahxixb .gt_font_normal { font-weight: normal; }
#  #tmfhahxixb .gt_font_bold { font-weight: bold; }
#  #tmfhahxixb .gt_font_italic { font-style: italic; }
#  #tmfhahxixb .gt_super { font-size: 65%; }
#  #tmfhahxixb .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #tmfhahxixb .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #tmfhahxixb .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #tmfhahxixb .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #tmfhahxixb .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #tmfhahxixb .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/index.qmd">Introduction à la partie 3: modéliser</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #5 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/0_preprocessing.qmd">Préparation des données pour construire un modèle</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #5 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/1_modelevaluation.qmd">Evaluer la qualité d'un modèle</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #5 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/2_classification.qmd">Découverte de la classification avec les arbres de décision</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #5 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/3_regression.qmd">Introduction à la régression</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #6 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/4_featureselection.qmd">Sélection de variables : une introduction</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #6 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/5_clustering.qmd">Introduction à l'apprentissage non supervisé avec le clustering</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #6 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/6_pipeline.qmd">Premier pas vers l'industrialisation avec les pipelines scikit</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/modelisation/7_mlapi.qmd">Mettre à disposition un modèle par le biais d'une API</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Natural Language Processing (NLP)

# %% [raw]
# <div id="cvnqyepzfn" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #cvnqyepzfn table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #cvnqyepzfn thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #cvnqyepzfn p { margin: 0; padding: 0; }
#  #cvnqyepzfn .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #cvnqyepzfn .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #cvnqyepzfn .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #cvnqyepzfn .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #cvnqyepzfn .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #cvnqyepzfn .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #cvnqyepzfn .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #cvnqyepzfn .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #cvnqyepzfn .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #cvnqyepzfn .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #cvnqyepzfn .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #cvnqyepzfn .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #cvnqyepzfn .gt_spanner_row { border-bottom-style: hidden; }
#  #cvnqyepzfn .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #cvnqyepzfn .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #cvnqyepzfn .gt_from_md> :first-child { margin-top: 0; }
#  #cvnqyepzfn .gt_from_md> :last-child { margin-bottom: 0; }
#  #cvnqyepzfn .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #cvnqyepzfn .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #cvnqyepzfn .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #cvnqyepzfn .gt_row_group_first td { border-top-width: 2px; }
#  #cvnqyepzfn .gt_row_group_first th { border-top-width: 2px; }
#  #cvnqyepzfn .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #cvnqyepzfn .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #cvnqyepzfn .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #cvnqyepzfn .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #cvnqyepzfn .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #cvnqyepzfn .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #cvnqyepzfn .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #cvnqyepzfn .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #cvnqyepzfn .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #cvnqyepzfn .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #cvnqyepzfn .gt_left { text-align: left; }
#  #cvnqyepzfn .gt_center { text-align: center; }
#  #cvnqyepzfn .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #cvnqyepzfn .gt_font_normal { font-weight: normal; }
#  #cvnqyepzfn .gt_font_bold { font-weight: bold; }
#  #cvnqyepzfn .gt_font_italic { font-style: italic; }
#  #cvnqyepzfn .gt_super { font-size: 65%; }
#  #cvnqyepzfn .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #cvnqyepzfn .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #cvnqyepzfn .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #cvnqyepzfn .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #cvnqyepzfn .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #cvnqyepzfn .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/NLP/index.qmd">Introduction à la partie 4 : Natural Language Processing (NLP)</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E9ECEF;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/NLP/01_intro.qmd">Nettoyer et structurer l'information dans les données textuelles</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #7 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/NLP/02_exoclean.qmd">L'analyse fréquentiste par l'approche bag-of-words : intérêt et limites</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #7 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><a href="../../content/NLP/03_embedding.qmd">Les embeddings, ou comment synthétiser l'information textuelle</a></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div class="cell raw">
# <span style="white-space:nowrap;">
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# France
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M167 0h178l25.9 252.3L345 512H167l-29.8-253.4z"></path><path fill="#0052b4" d="M0 0h167v512H0z"></path><path fill="#d80027" d="M345 0h167v512H345z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# <div class="cell raw">
# <svg xmlns="http://www.w3.org/2000/svg" aria-hidden="true" role="img" width="512" height="512" viewbox="0 0 512 512" style="vertical-align:-0.125em;image-rendering:optimizeQuality;height:1em;width:1em;">
# </div>
# <div class="cell raw">
# <title>
# </div>
# United States
# <div class="cell raw">
# </title>
# </div>
# <mask id="a"><circle cx="256" cy="256" r="256" fill="#fff"></circle></mask><g mask="url(#a)"><path fill="#eee" d="M256 0h256v64l-32 32 32 32v64l-32 32 32 32v64l-32 32 32 32v64l-256 32L0 448v-64l32-32-32-32v-64z"></path><path fill="#d80027" d="M224 64h288v64H224Zm0 128h288v64H256ZM0 320h512v64H0Zm0 128h512v64H0Z"></path><path fill="#0052b4" d="M0 0h256v256H0Z"></path><path fill="#eee" d="m187 243 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67zm162-81 57-41h-70l57 41-22-67zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Zm162-82 57-41h-70l57 41-22-67Zm-81 0 57-41H93l57 41-22-67zm-81 0 57-41H12l57 41-22-67Z"></path></g>
# <div class="cell raw">
# </svg>
# </div>
# </span></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #7 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M64 96c0-35.3 28.7-64 64-64H512c35.3 0 64 28.7 64 64V352H512V96H128V352H64V96zM0 403.2C0 392.6 8.6 384 19.2 384H620.8c10.6 0 19.2 8.6 19.2 19.2c0 42.4-34.4 76.8-76.8 76.8H76.8C34.4 480 0 445.6 0 403.2zM281 209l-31 31 31 31c9.4 9.4 9.4 24.6 0 33.9s-24.6 9.4-33.9 0l-48-48c-9.4-9.4-9.4-24.6 0-33.9l48-48c9.4-9.4 24.6-9.4 33.9 0s9.4 24.6 0 33.9zM393 175l48 48c9.4 9.4 9.4 24.6 0 33.9l-48 48c-9.4 9.4-24.6 9.4-33.9 0s-9.4-24.6 0-33.9l31-31-31-31c-9.4-9.4-9.4-24.6 0-33.9s24.6-9.4 33.9 0z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website and exercise notebooks
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# ### Git

# %% [raw]
# <div id="lkgowujetl" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Libre+Franklin&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=Source+Sans+Pro&display=swap');
# #lkgowujetl table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #lkgowujetl thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #lkgowujetl p { margin: 0; padding: 0; }
#  #lkgowujetl .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #FFFFFF; font-size: 16px; font-weight: normal; font-style: normal; background-color: #333333; width: auto; border-top-style: none; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #333333; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; border-left-style: none; border-left-width: 2px; border-left-color: #333333; }
#  #lkgowujetl .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #lkgowujetl .gt_title { color: #FFFFFF; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #333333; border-bottom-width: 0; }
#  #lkgowujetl .gt_subtitle { color: #FFFFFF; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #333333; border-top-width: 0; }
#  #lkgowujetl .gt_heading { background-color: #333333; text-align: left; border-bottom-color: #333333; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #lkgowujetl .gt_bottom_border { border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #lkgowujetl .gt_col_headings { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #lkgowujetl .gt_col_heading { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #lkgowujetl .gt_column_spanner_outer { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #lkgowujetl .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #lkgowujetl .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #lkgowujetl .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 3px; border-bottom-color: white; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #lkgowujetl .gt_spanner_row { border-bottom-style: hidden; }
#  #lkgowujetl .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #lkgowujetl .gt_empty_group_heading { padding: 0.5px; color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #lkgowujetl .gt_from_md> :first-child { margin-top: 0; }
#  #lkgowujetl .gt_from_md> :last-child { margin-bottom: 0; }
#  #lkgowujetl .gt_row { padding-top: 7px; padding-bottom: 7px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #lkgowujetl .gt_stub { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #lkgowujetl .gt_stub_row_group { color: #FFFFFF; background-color: #333333; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #lkgowujetl .gt_row_group_first td { border-top-width: 2px; }
#  #lkgowujetl .gt_row_group_first th { border-top-width: 2px; }
#  #lkgowujetl .gt_striped { color: #333333; background-color: #F4F4F4; }
#  #lkgowujetl .gt_table_body { border-top-style: none; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #333333; }
#  #lkgowujetl .gt_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #lkgowujetl .gt_first_summary_row { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; }
#  #lkgowujetl .gt_last_summary_row_top { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #lkgowujetl .gt_grand_summary_row { color: #FFFFFF; background-color: #333333; text-transform: inherit; padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; }
#  #lkgowujetl .gt_first_grand_summary_row_bottom { border-top-style: double; border-top-width: 6px; border-top-color: #D3D3D3; }
#  #lkgowujetl .gt_last_grand_summary_row_top { border-bottom-style: double; border-bottom-width: 6px; border-bottom-color: #D3D3D3; }
#  #lkgowujetl .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #lkgowujetl .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #lkgowujetl .gt_left { text-align: left; }
#  #lkgowujetl .gt_center { text-align: center; }
#  #lkgowujetl .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #lkgowujetl .gt_font_normal { font-weight: normal; }
#  #lkgowujetl .gt_font_bold { font-weight: bold; }
#  #lkgowujetl .gt_font_italic { font-style: italic; }
#  #lkgowujetl .gt_super { font-size: 65%; }
#  #lkgowujetl .gt_footnotes { color: font-color(#333333); background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #lkgowujetl .gt_footnote { margin: 0px; font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; }
#  #lkgowujetl .gt_sourcenotes { color: #FFFFFF; background-color: #333333; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #lkgowujetl .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #lkgowujetl .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #lkgowujetl .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>

# %% [markdown]
# <table class="gt_table" data-quarto-postprocess="true" style="table-layout: fixed;" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
# <col style="width: 60%" />
# <col />
# <col />
# <col />
# </colgroup>
# <thead>
# <tr class="gt_col_headings">
# <th id="title_link" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Title</strong></th>
# <th id="langs" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Available in</strong></th>
# <th id="classroom_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Learning mode</strong></th>
# <th id="material_icon" class="gt_col_heading gt_columns_bottom_border gt_left" data-quarto-table-cell-role="th" style="color: white; font-family: Source Sans Pro; text-transform: uppercase" scope="col"><strong>Resource type</strong></th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #3 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #3 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# <tr>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro">None</td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 640 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.25em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M160 64c0-35.3 28.7-64 64-64H576c35.3 0 64 28.7 64 64V352c0 35.3-28.7 64-64 64H336.8c-11.8-25.5-29.9-47.5-52.4-64H384V320c0-17.7 14.3-32 32-32h64c17.7 0 32 14.3 32 32v32h64V64L224 64v49.1C205.2 102.2 183.3 96 160 96V64zm0 256c-53 0-96-43-96-96s43-96 96-96s96 43 96 96s-43 96-96 96zm-26.7 32h53.3C260.3 352 320 411.7 320 485.3c0 14.7-11.9 26.7-26.7 26.7H26.7C11.9 512 0 500.1 0 485.3C0 411.7 59.7 352 133.3 352z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Lesson #3 or self learning
# </span>
# </div>
# </div></td>
# <td class="gt_row gt_left" style="font-family: Source Sans Pro"><div>
# <div style="line-height:14px;">
# <div class="cell raw">
# <span style="
#                 font-weight:bold;
#                 font-variant:small-caps;
#                 color:black;
#                 font-size:14px;
#             ">
# </div>
# <div class="cell raw">
# <svg viewbox="0 0 512 512" preserveaspectratio="none" aria-hidden="true" role="img" class="fa" style="fill:#E16462;fill-opacity:1;stroke-opacity:None;height:1em;width:1.0em;margin-left:auto;margin-right:0.2em;position:relative;vertical-align:-0.125em;overflow:visible;">
# </div>
# <path d="M352 96c0 53-43 96-96 96s-96-43-96-96s43-96 96-96s96 43 96 96zM240 248V512l-48.4-24.2c-20.9-10.4-43.5-17-66.8-19.3l-96-9.6C12.5 457.2 0 443.5 0 427V224c0-17.7 14.3-32 32-32H62.3c63.6 0 125.6 19.6 177.7 56zm32 264V248c52.1-36.4 114.1-56 177.7-56H480c17.7 0 32 14.3 32 32V427c0 16.4-12.5 30.2-28.8 31.8l-96 9.6c-23.2 2.3-45.9 8.9-66.8 19.3L272 512z"></path>
# <div class="cell raw">
# </svg>
# </div>
# </span>
# </div>
# <div style="line-height:10px;">
# <span style="
#                 font-weight:normal;
#                 color:grey;
#                 font-size:10px;
#             ">
# Read from website
# </span>
# </div>
# </div></td>
# </tr>
# </tbody>
# </table>

# %% [raw]
# </div>

# %% [markdown]
# # Références
#
# Davenport, Thomas H, et DJ Patil. 2012. « Data scientist, the sexiest job of the 21st century ». *Harvard business review* 90 (5): 70‑76. <https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century>.
#
# ———. 2022. « Is data scientist still the sexiest job of the 21st century? » *Harvard Business Review* 90.
#
# Galiana, Lino, et Olivier Lefebvre. 2026. « Qu’apportent les métiers de la data à la statistique publique ? » *Courrier des Statistiques*, nᵒ 15: 95‑116. <https://insee.hal.science/hal-05684911v1>.
#
# Kapoor, Sayash, et Arvind Narayanan. 2022. « Leakage and the Reproducibility Crisis in ML-based Science ». arXiv. <https://doi.org/10.48550/ARXIV.2207.07048>.
#
# Kosmyna, Nataliya, Eugene Hauptmann, Ye Tong Yuan, Jessica Situ, Xian-Hao Liao, Ashly Vivian Beresnitzky, Iris Braunstein, et Pattie Maes. 2025. « Your brain on ChatGPT: Accumulation of cognitive debt when using an AI assistant for essay writing task ». *arXiv preprint arXiv:2506.08872* 4: 206.
#
# Russell, Stuart J., et Peter Norvig. 2020. *Artificial Intelligence: A Modern Approach (4th Edition)*. Pearson. <http://aima.cs.berkeley.edu/>.
